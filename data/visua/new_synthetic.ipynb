# %%
"""
Split data

"""

import numpy as np

data = np.load('/home/vimlab/workspace/source/visualization/my_visualization/synthetic/all(5parts)/my_ntu_denoised_class6_centered2_zero_reduce2_joint_synthetic_poses_OD_data.npz')
num = 644872
num2 = 161218

syn_train_la = data['train'][:num]
syn_train_ra = data['train'][num:2*num]
syn_train_ll = data['train'][2*num:3*num]
syn_train_rl = data['train'][3*num:4*num]
syn_train_body = data['train'][4*num:5*num+4]
syn_train_ori = data['train'][5*num+4:]
syn_test_la = data['test'][:num2]
syn_test_ra = data['test'][num2:2*num2]
syn_test_ll = data['test'][2*num2:3*num2]
syn_test_rl = data['test'][3*num2:4*num2]
syn_test_body = data['test'][4*num2:5*num2+1]
syn_test_ori = data['test'][5*num2+1:]

t_syn_train_la = data['train_target'][:numtrain_ra = data['train_target'][num:2*num]
t_syn_train_la = data['train_target'][:numtrain_ra = data['train_target'][num:2*num]
t_syn_train_ll = data['train_target'][2*num:3*num]
t_syn_train_rl = data['train_target'][3*num:4*num]
t_syn_train_body = data['train_target'][4*num:5*num+4]
t_syn_train_ori = data['train_target'][5*num+4:]
t_syn_test_la = data['test_target'][:num2]
t_syn_test_ra = data['test_target'][num2:2*num2]
t_syn_test_ll = data['test_target'][2*num2:3*num2]
t_syn_test_rl = data['test_target'][3*num2:4*num2]
t_syn_test_body = data['test_target'][4*num2:5*num2+1]
t_syn_test_ori = data['test_target'][5*num2+1:]

# print(syn_train_la.shape)
# print(syn_train_body.shape)
# print(syn_train_ori.shape)
# print(syn_test_la.shape)
# print(syn_test_body.shape)
# print(syn_test_ori.shape)

# print(np.unique(syn_test_body, return_counts=True))

np.savez('./synthetic/all(5parts)/my_ntu_denoised_split_class6_centered2_zero_reduce2_joint_synthetic_poses_OD_data.npz', 
         train_left_arm = syn_train_la,
         train_right_arm = syn_train_ra,
         train_left_leg = syn_train_ll,
         train_right_leg = syn_train_rl,
         train_body = syn_train_body,
         train_none = syn_train_ori,
         test_left_arm = syn_test_la,
         test_right_arm = syn_test_ra,
         test_left_leg = syn_test_ll,
         test_right_leg = syn_test_rl,
         test_body = syn_test_body,
         test_none = syn_test_ori,
         train_target_left_arm = t_syn_train_la,
         train_target_right_arm = t_syn_train_ra,
         train_target_left_leg = t_syn_train_ll,
         train_target_right_leg = t_syn_train_rl,
         train_target_body = t_syn_train_body,
         train_target_none = t_syn_train_ori,
         test_target_left_arm = t_syn_test_la,
         test_target_right_arm = t_syn_test_ra,
         test_target_left_leg = t_syn_test_ll,
         test_target_right_leg = t_syn_test_rl,
         test_target_body = t_syn_test_body,
         test_target_none = t_syn_test_ori)
